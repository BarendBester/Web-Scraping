# %% [markdown]
# ## EDA with Data Analysis
# ### Import Pandas

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import os

# %%
#create path
path = r'C:\Users\beatr\Documents\28_07_2023_practice'

# %%
#import data set
df = pd.read_csv(os.path.join(path, '02-Data', 'Original', 'world_population.csv'), index_col = False)

# %%
df
# Out:
#     Rank CCA3            Country           Capital Continent  2022 Population  \
# 0     36  AFG        Afghanistan             Kabul      Asia      41128771.00
# 1    138  ALB            Albania            Tirana    Europe       2842321.00
# 2     34  DZA            Algeria           Algiers    Africa      44903225.00
# 3    213  ASM     American Samoa         Pago Pago   Oceania         44273.00
# 4    203  AND            Andorra  Andorra la Vella    Europe         79824.00
# ..   ...  ...                ...               ...       ...              ...
# 229  226  WLF  Wallis and Futuna          Mata-Utu   Oceania         11572.00
# 230  172  ESH     Western Sahara          El Aaiún    Africa        575986.00
# 231   46  YEM              Yemen             Sanaa      Asia      33696614.00
# 232   63  ZMB             Zambia            Lusaka    Africa      20017675.00
# 233   74  ZWE           Zimbabwe            Harare    Africa      16320537.00
#
# ...

# %%
# set the decimals if scientific notation displayed
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# see some of the data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    object
#  1   CCA3                         233 non-null    object
#  2   Country                      233 non-null    object
#  3   Capital                      233 non-null    object
#  4   Continent                    233 non-null    object
#  5   2022 Population              229 non-null    float64
#  6   2020 Population              232 non-null    float64
#  7   2015 Population              229 non-null    float64
#  8   2010 Population              226 non-null    float64
#  9   2000 Population              226 non-null    float64
#  10  1990 Population              228 non-null    float64
#  11  1980 Population              228 non-null    float64
# ...

# %%
# see basic descriptic stats
df.describe()
# Out:
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# count           229.00           232.00           229.00           226.00
# mean       33306235.13      32297515.73      30788529.17      29027188.01
# std       136713676.19     134699756.92     130357155.49     124952276.10
# min             510.00           520.00           564.00           596.00
# 25%          409984.00        403763.75        392697.00        377999.25
# 50%         5643453.00       5418260.00       5064386.00       4774904.00
# 75%        22593590.00      21298686.50      19205178.00      16642616.50
# max      1425887337.00    1424929781.00    1393715448.00    1348191368.00
#
#        2000 Population  1990 Population  1980 Population  1970 Population  \
# count           226.00           228.00           228.00           229.00
# mean       25709707.38      18327160.12      15375616.65      15060988.90
# std       112313551.99      80055283.72      68122311.30      67402728.46
# ...

# %%
# see null values
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           1
# Country                        1
# Capital                        1
# Continent                      1
# 2022 Population                5
# 2020 Population                2
# 2015 Population                5
# 2010 Population                8
# 2000 Population                8
# 1990 Population                6
# 1980 Population                6
# 1970 Population                5
# Area (km²)                     3
# Density (per km²)              5
# Growth Rate                    3
# World Population Percentage    1
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           233
# Country                        233
# Capital                        233
# Continent                        6
# 2022 Population                229
# 2020 Population                232
# 2015 Population                229
# 2010 Population                226
# 2000 Population                226
# 1990 Population                228
# 1980 Population                228
# 1970 Population                229
# Area (km²)                     230
# Density (per km²)              229
# Growth Rate                    178
# World Population Percentage     69
# dtype: int64

# %%
df
# Out:
#     Rank CCA3            Country           Capital Continent  2022 Population  \
# 0     36  AFG        Afghanistan             Kabul      Asia      41128771.00
# 1    138  ALB            Albania            Tirana    Europe       2842321.00
# 2     34  DZA            Algeria           Algiers    Africa      44903225.00
# 3    213  ASM     American Samoa         Pago Pago   Oceania         44273.00
# 4    203  AND            Andorra  Andorra la Vella    Europe         79824.00
# ..   ...  ...                ...               ...       ...              ...
# 229  226  WLF  Wallis and Futuna          Mata-Utu   Oceania         11572.00
# 230  172  ESH     Western Sahara          El Aaiún    Africa        575986.00
# 231   46  YEM              Yemen             Sanaa      Asia      33696614.00
# 232   63  ZMB             Zambia            Lusaka    Africa      20017675.00
# 233   74  ZWE           Zimbabwe            Harare    Africa      16320537.00
#
# ...

# %%
df.sort_values(by = '2022 Population', ascending = False).head(10)
# Out:
#     Rank CCA3     Country      Capital      Continent  2022 Population  \
# 41     1  CHN       China      Beijing           Asia    1425887337.00
# 92     2  IND       India    New Delhi           Asia    1417173173.00
# 93     4  IDN   Indonesia      Jakarta           Asia     275501339.00
# 156    5  PAK    Pakistan    Islamabad           Asia     235824862.00
# 149    6  NGA     Nigeria        Abuja         Africa     218541212.00
# 27     7  BRA      Brazil     Brasilia  South America     215313498.00
# 16     8  BGD  Bangladesh        Dhaka           Asia     171186372.00
# 171    9  RUS      Russia       Moscow         Europe     144713314.00
# 131   10  MEX      Mexico  Mexico City  North America     127504125.00
# 102   11  JPN       Japan        Tokyo           Asia     123951692.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 41     1424929781.00    1393715448.00    1348191368.00    1264099069.00
# ...

# %%
df.sort_values(by = 'World Population Percentage', ascending = False).head(10)
# Out:
#     Rank CCA3     Country      Capital      Continent  2022 Population  \
# 41     1  CHN       China      Beijing           Asia    1425887337.00
# 92     2  IND       India    New Delhi           Asia    1417173173.00
# 93     4  IDN   Indonesia      Jakarta           Asia     275501339.00
# 156    5  PAK    Pakistan    Islamabad           Asia     235824862.00
# 149    6  NGA     Nigeria        Abuja         Africa     218541212.00
# 27     7  BRA      Brazil     Brasilia  South America     215313498.00
# 16     8  BGD  Bangladesh        Dhaka           Asia     171186372.00
# 171    9  RUS      Russia       Moscow         Europe     144713314.00
# 131   10  MEX      Mexico  Mexico City  North America     127504125.00
# 63    12  ETH    Ethiopia  Addis Ababa         Africa     123379924.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 41     1424929781.00    1393715448.00    1348191368.00    1264099069.00
# ...

# %%
df.corr()
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_3768\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              2022 Population  2020 Population  \
# 2022 Population                         1.00             1.00
# 2020 Population                         1.00             1.00
# 2015 Population                         1.00             1.00
# 2010 Population                         1.00             1.00
# 2000 Population                         0.99             1.00
# 1990 Population                         0.99             0.99
# 1980 Population                         0.99             0.99
# 1970 Population                         0.97             0.98
# Area (km²)                              0.43             0.44
# ...

# %%
#create a heatmap to see how data is correlated

sns.heatmap(df.corr(), annot = True)

plt.rcParams['figure.figsize'] = (30,7)

plt.show()
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_3768\4226959484.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df.groupby('Continent').mean()
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_3768\3700721160.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Continent').mean()
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa             25455879.68      23871435.26      21419703.57
# Asia               96327387.31      94955134.37      89165003.64
# Europe             15055371.82      14915843.92      15027454.12
# North America       6718109.72       6622938.21       6301950.62
# Oceania             2046386.32       1910148.96       1756664.48
# South America      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa             18898197.31      14598365.95      11376964.52
# ...

# %%
df[df['Continent'].str.contains('Oceania').fillna(False)]
# Out:
#     Rank CCA3                   Country       Capital Continent  \
# 3    213  ASM            American Samoa     Pago Pago   Oceania
# 11    55  AUS                 Australia      Canberra   Oceania
# 44   223  COK              Cook Islands        Avarua   Oceania
# 66   162  FJI                      Fiji          Suva   Oceania
# 70   183  PYF          French Polynesia       Papeete   Oceania
# 81   191  GUM                      Guam       Hagåtña   Oceania
# 107  192  KIR                  Kiribati        Tarawa   Oceania
# 126  215  MHL          Marshall Islands        Majuro   Oceania
# 132  194  FSM                Micronesia       Palikir   Oceania
# 142  225  NRU                     Nauru         Yaren   Oceania
# 145  185  NCL             New Caledonia        Nouméa   Oceania
# 146  123  NZL               New Zealand    Wellington   Oceania
# 150  232  NIU                      Niue         Alofi   Oceania
# 153  210  NFK  Northern Mariana Islands        Saipan   Oceania
# ...

# %%
df.groupby('Continent').mean().sort_values(by = '2022 Population', ascending = False)
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_3768\573464841.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Continent').mean().sort_values(by = '2022 Population', ascending = False)
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               96327387.31      94955134.37      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25455879.68      23871435.26      21419703.57
# Europe             15055371.82      14915843.92      15027454.12
# North America       6718109.72       6622938.21       6301950.62
# Oceania             2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# ...

# %%
df2 = df.groupby('Continent').mean().sort_values(by = '2022 Population', ascending = False)
df2
# Out:
# C:\Users\beatr\AppData\Local\Temp\ipykernel_3768\242022662.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby('Continent').mean().sort_values(by = '2022 Population', ascending = False)
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               96327387.31      94955134.37      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25455879.68      23871435.26      21419703.57
# Europe             15055371.82      14915843.92      15027454.12
# North America       6718109.72       6622938.21       6301950.62
# Oceania             2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# ...

# %%
df2.plot()
# Out:
# <Axes: xlabel='Continent'>

# %%
df2 = df2.transpose()

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df2 = df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by = '2022 Population', ascending = False )
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       2951442.72       3721880.59       4440581.87
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America       5222334.10       5936866.82       6301950.62
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df.boxplot(figsize = (20,10))
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# Rank                            object
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
# select all strings
df.select_dtypes(include = 'object' )
# Out:
#     Rank CCA3            Country           Capital Continent
# 0     36  AFG        Afghanistan             Kabul      Asia
# 1    138  ALB            Albania            Tirana    Europe
# 2     34  DZA            Algeria           Algiers    Africa
# 3    213  ASM     American Samoa         Pago Pago   Oceania
# 4    203  AND            Andorra  Andorra la Vella    Europe
# ..   ...  ...                ...               ...       ...
# 229  226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  172  ESH     Western Sahara          El Aaiún    Africa
# 231   46  YEM              Yemen             Sanaa      Asia
# 232   63  ZMB             Zambia            Lusaka    Africa
# 233   74  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 5 columns]

# %%
# select all strings
df.select_dtypes(include = 'number')
# Out:
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# 2        44903225.00      43451666.00      39543154.00      35856344.00
# 3           44273.00         46189.00         51368.00         54849.00
# 4           79824.00         77700.00         71746.00         71519.00
# ..               ...              ...              ...              ...
# 229         11572.00         11655.00         12182.00         13142.00
# 230        575986.00        556048.00        491824.00        413296.00
# 231      33696614.00      32284046.00      28516545.00      24743946.00
# 232      20017675.00      18927715.00              NaN      13792086.00
# 233      16320537.00      15669666.00      14154937.00      12839771.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...
